# %%
print("hello rohit")
# Out:
# hello rohit

# %%
" hello welcome to adark city "
# Out:
# ' hello welcome to adark city '

# %%
print(2)
# Out:
# 2

# %%
type(2.3)
# Out:
# float

# %%
print("hello world " .upper())
print("adrak ".lower())
print("alive".title())
# Out:
# HELLO WORLD
# adrak
# Alive

# %%
message_1="I'am learning python "

# %%
message_2= "and it's fun !"

# %%
message= message_1+''+ message_2
message
# Out:
# "I'am learning python and it's fun !"

# %%
countries = ['united states','india ','china','brazil']
countries
# Out:
# ['united states', 'india ', 'china', 'brazil']

# %%
print(countries[0])
print(countries[1])
print(countries[2])
print(countries[3])
print
# Out:
# united states
# india
# china
# brazil
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
print(countries[0:2])
print(countries[0:])
print(countries[:3])
# Out:
# ['united states', 'india ']
# ['united states', 'india ', 'china', 'brazil']
# ['united states', 'india ', 'china']

# %%
countries = ['united states','india ','china','brazil']
countries.append('cannda')

# %%
countries
# Out:
# ['united states', 'india ', 'china', 'brazil', 'cannda']

# %%
countries = ['united states','india ','china','brazil']
countries.insert(0,'uk')

# %%
countries
# Out:
# ['uk', 'united states', 'india ', 'china', 'brazil']

# %%
countries_2 = ['uk ', 'germany', ' adrak ']
countries + countries_2
# Out:
# ['uk',
#  'united states',
#  'india ',
#  'china',
#  'brazil',
#  'uk ',
#  'germany',
#  ' adrak ']

# %%
print("hello world ")
# Out:
# hello world

# %%
3**4
# Out:
# 81

# %%
3+9
# Out:
# 12

# %%
print("hello world ".upper())
print("heloo world ". lower ())
print("hello world ".title())
# Out:
# HELLO WORLD
# heloo world
# Hello World

# %%
message_1="'I'am learning python "

# %%
message_2= " and it's fun "

# %%
message= message_1+''+message_2
message
# Out:
# "'I'am learning python  and it's fun "

# %%
countries = ['united states ','india  ',' brazil ', 'uae ','china ','sri lanka ']
countries
# Out:
# ['united states ', 'india  ', ' brazil ', 'uae ', 'china ', 'sri lanka ']

# %%
print(countries[0])
# Out:
# united states

# %%
print(countries[0])
print(countries[1])
print(countries[2])
print(countries[3])
# Out:
# united states
# india
#  brazil
# uae

# %%
print(countries[0:3])
print(countries[:3])
print(countries[0:])
# Out:
# ['united states ', 'india  ', ' brazil ']
# ['united states ', 'india  ', ' brazil ']
# ['united states ', 'india  ', ' brazil ', 'uae ', 'china ', 'sri lanka ']

# %%
countries = ['United States', 'India', 'China', 'Brazil']
countries.append("canada")
countries
# Out:
# ['United States', 'India', 'China', 'Brazil', 'canada']

# %%
countries = ['United States', 'India', 'China', 'Brazil']
countries.insert(3,'russia')
countries
# Out:
# ['United States', 'India', 'China', 'russia', 'Brazil']

# %%
countries_2 = ['uk ','germany','austria']
countries + countries_2
# Out:
# ['United States',
#  'India',
#  'China',
#  'russia',
#  'Brazil',
#  'uk ',
#  'germany',
#  'austria']

# %%
nested_list = [ countries , countries_2 ]
nested_list
# Out:
# [['United States', 'India', 'China', 'russia', 'Brazil'],
#  ['uk ', 'germany', 'austria']]

# %%
countries=[ 'us ','india','china ', 'uae ']
print(countries)
# Out:
# ['us ', 'india', 'china ', 'uae ']

# %% [raw]
# countries.remove(us)

# %%
countries
# Out:
# ['us ', 'india', 'china ', 'uae ']

# %% [raw]
# countries.remove('us')

# %%
countries
# Out:
# ['us ', 'india', 'china ', 'uae ']

# %%
numbers = [1,4,3,5,8,2]
numbers.sort()
numbers
# Out:
# [1, 2, 3, 4, 5, 8]

# %%
numbers = [1,4,3,5,8,2]
numbers.sort(reverse=True)
numbers
# Out:
# [8, 5, 4, 3, 2, 1]

# %%
numbers[2]=10
numbers
# Out:
# [8, 5, 10, 3, 2, 1]

# %%
new_list = countries[:]
print(new_list)
new_list_2=countries.copy ()
print(new_list)
# Out:
# ['us ', 'india', 'china ', 'uae ']
# ['us ', 'india', 'china ', 'uae ']

# %%
my_data={'name':'frank','age':26}

# %%
my_data['name']
# Out:
# 'frank'

# %%
my_data.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
my_data.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
my_data.values()
# Out:
# dict_values(['frank', 26])

# %%
my_data.items()
# Out:
# dict_items([('name', 'frank'), ('age', 26)])

# %%
my_data
# Out:
# {'name': 'frank', 'age': 26}

# %%
my_data.update({'height':1.8,'language':['English','spanish ']})

# %%
my_data
# Out:
# {'name': 'frank',
#  'age': 26,
#  'height': 1.8,
#  'language': ['English', 'spanish ']}

# %%
new_dist=my_data.copy()
new_dist
# Out:
# {'name': 'frank',
#  'age': 26,
#  'height': 1.8,
#  'language': ['English', 'spanish ']}

# %%
my_data.pop('height')
# Out:
# 1.8

# %%
my_data
# Out:
# {'name': 'frank', 'age': 26, 'language': ['English', 'spanish ']}

# %%
del my_data['language']

# %%
my_data
# Out:
# {'name': 'frank', 'age': 26}
